# %% [markdown]
# ## Initialisation
#
# Connexion à la base PostgreSQL.

# %%
from sqlalchemy import create_engine, text, URL

DB_USER = "indusense_user"
DB_PASSWORD = "ThEP@ssW0rd"
DB_HOST = "localhost"
DB_PORT = 5432
DB_NAME = "indusense_db"

url = URL.create(
    drivername="postgresql+psycopg2",
    username=DB_USER,
    password=DB_PASSWORD,
    host=DB_HOST,
    port=DB_PORT,
    database=DB_NAME,
)

engine = create_engine(url)

try:
    with engine.connect() as conn:
        conn.execute(text("SELECT 1"))
    print(f"✅ Connexion à PostgreSQL réussie ({DB_HOST}:{DB_PORT}/{DB_NAME})")
except Exception as e:
    print(f"❌ Échec de connexion : {e}")

# %% [markdown]
# ## Chargement du gold dataset de référence
#
# Chargement du CSV `gold_dataset_20260622-080603.csv` puis insertion dans la table `gold_dataset`.

# %%
import pandas as pd

gold_dataset_df = pd.read_csv("artifacts/ingestions/gold/gold_dataset_20260622-080603.csv")
gold_dataset_df.to_sql("gold_dataset", engine, if_exists="replace", index=False)

print(f"✅ gold_dataset : {len(gold_dataset_df)} lignes insérées, {gold_dataset_df.shape[1]} colonnes")
